# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Upload Data

# %%
df=pd.read_csv(r'C:\Users\saura\Downloads\archive (7)\country_wise_latest.csv')

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # In Data Analysis what we are going to do is¶
# 1.Missing value
#
# 2.Explore about numerical variable
#
# 3.Explore about catigorical variable
#
# 4.Finding relationship between feature

# %%
df.shape
# Out:
# (187, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Null Value

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# ### Representing  null value by graph

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Find Corelation

# %%
df.corr()
# Out:
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                   0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered                0.906377  0.832098   1.000000  0.682103   0.818942
# Active                   0.927018  0.871586   0.682103  1.000000   0.851190
# New cases                0.909720  0.806975   0.818942  0.851190   1.000000
# New deaths               0.871683  0.814161   0.820338  0.781123   0.935947
# New recovered            0.859252  0.765114   0.919203  0.673887   0.914765
# Deaths / 100 Cases       0.063550  0.251565   0.048438  0.054380   0.020104
# Recovered / 100 Cases   -0.064815 -0.114529   0.026610 -0.132618  -0.078666
# Deaths / 100 Recovered   0.025175  0.169006  -0.027277  0.058386  -0.011637
# Confirmed last week      0.999127  0.939082   0.899312  0.931459   0.896084
# ...

# %% [markdown]
# ### Representing corelation by graph

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Statistical Analysis

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# ### The describe () function in Python summarizes statistics. This function returns the count, mean, standard deviation, minimum and maximum values, and the quantiles of the data.

# %% [markdown]
# # EDA & Vizualisation

# %% [markdown]
# ### How many country and who region present in this data?

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
number_of_country=df['Country/Region'].nunique()

# %%
number_of_country
# Out:
# 187

# %%
number_of_who=df['WHO Region'].nunique()

# %%
number_of_who
# Out:
# 6

# %% [markdown]
# There are  187 countries and 6 different who region present in this data

# %% [markdown]
# ### Which WHO region have max active and min active case

# %%
df['WHO Region'].value_counts()
# Out:
# Europe                   56
# Africa                   48
# Americas                 35
# Eastern Mediterranean    22
# Western Pacific          16
# South-East Asia          10
# Name: WHO Region, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='WHO Region',y='Active',data=df)
# Out:
# <AxesSubplot:xlabel='WHO Region', ylabel='Active'>

# %% [markdown]
# America region have most active case  and Africa have min active case

# %% [markdown]
# # Which WHO region have max and min deaths case

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='WHO Region',y='Deaths',data=df)
# Out:
# <AxesSubplot:xlabel='WHO Region', ylabel='Deaths'>

# %% [markdown]
# America region have max deaths and Africa have min deaths case

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Which WHO region have max  and min recovered

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='WHO Region',y='Recovered',data=df)
# Out:
# <AxesSubplot:xlabel='WHO Region', ylabel='Recovered'>

# %% [markdown]
# America region have max recovered and Africa have min recoveredcase

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# ### HOW MANY CASES CONFIRMED,DEATH,RECOVERED,ACTIVE CASE IN INDIA?

# %%
df[df['Country/Region']=='India'][['Confirmed','Deaths', 'Recovered', 'Active']]
# Out:
#     Confirmed  Deaths  Recovered  Active
# 79    1480073   33408     951166  495499

# %% [markdown]
# ### HOW MANY CASES CONFIRMED,DEATH,RECOVERED,ACTIVE CASE IN FRANCE ?

# %%
df[df['Country/Region']=='France'][['Confirmed','Deaths', 'Recovered', 'Active']]
# Out:
#     Confirmed  Deaths  Recovered  Active
# 61     220352   30212      81212  108928

# %% [markdown]
# ### How many death,active,recovered ,confirmed in the world due to Covid-19

# %%
total_death=df.Deaths.sum()
total_death
# Out:
# 654036

# %%
total_active_case=df.Active.sum()
total_active_case
# Out:
# 6358362

# %%
# TOTAL RECOVERD CASE
total_recoverd_case=df.Recovered.sum()
total_recoverd_case
# Out:
# 9468087

# %%
# TOTAL CONFIRMED CASE
total_confirmed_case=df.Confirmed.sum()
total_confirmed_case
# Out:
# 16480485

# %% [markdown]
# ###### Total active, confirmed ,deaths,recovered by graph

# %%
data=[total_death,total_active_case,total_recoverd_case,total_confirmed_case]
mylabels=['total_deaths','total_active','total_recovered','total_confirmed']
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2e8ec184e50>,
# ...
#  [Text(1.0978633904613848, 0.06852719084154281, 'total_deaths'),
#   Text(0.8191729657985588, 0.7341359901985417, 'total_active'),
#   Text(-0.6816776763625454, 0.8633165963590419, 'total_recovered'),
#   Text(9.011575305750074e-08, -1.0999999999999963, 'total_confirmed')],
#  [Text(0.5988345766153007, 0.037378467731750624, '1.98'),
#   Text(0.4468216177083048, 0.4004378128355682, '19.29'),
#   Text(-0.3718241871068429, 0.47089996165038644, '28.73'),
#   Text(4.9154047122273126e-08, -0.599999999999998, '50.00')])

# %% [markdown]
# #### Which country have max or min active case?

# %%
max_active_case=df[df['Active'].max()==df['Active']][['Country/Region','Active']]

# %%
max_active_case
# Out:
#     Country/Region   Active
# 173             US  2816444

# %%
min_active_case=df[df['Active'].min()==df['Active']][['Country/Region','Active']]

# %%
min_active_case
# Out:
#     Country/Region  Active
# 24          Brunei       0
# 49        Dominica       0
# 69         Grenada       0
# 75        Holy See       0
# 143     San Marino       0

# %% [markdown]
# #### which country has max or min deaths

# %%
#WHICH COUNTRY HAS MAX DEATH
df[df['Deaths'].max()==df['Deaths']][['Country/Region','Deaths']]
# Out:
#     Country/Region  Deaths
# 173             US  148011

# %%
# WHICH COUNTRY HAS  MIN DEATH
df[df['Deaths'].min()==df['Deaths']][['Country/Region','Deaths']]
# Out:
#                        Country/Region  Deaths
# 19                             Bhutan       0
# 30                           Cambodia       0
# 49                           Dominica       0
# 55                            Eritrea       0
# 59                               Fiji       0
# 68                          Greenland       0
# 69                            Grenada       0
# 75                           Holy See       0
# 94                               Laos       0
# 114                          Mongolia       0
# 130                  Papua New Guinea       0
# 140             Saint Kitts and Nevis       0
# 141                       Saint Lucia       0
# 142  Saint Vincent and the Grenadines       0
# 148                        Seychelles       0
# 168                       Timor-Leste       0
# 181                           Vietnam       0

# %% [markdown]
# #### Which country have max or min recovered case

# %%
# WHICH COUNTRY HAS MAX RECOVERED

df[df['Recovered'].max()==df['Recovered']][['Country/Region','Recovered']]
# Out:
#    Country/Region  Recovered
# 23         Brazil    1846641

# %%
# WHICH COUNTRY HAS MIN RECOVERD
df[df['Recovered'].min()==df['Recovered']][['Country/Region','Recovered']]
# Out:
#     Country/Region  Recovered
# 32          Canada          0
# 117     Mozambique          0
# 147         Serbia          0
# 161         Sweden          0
# 163          Syria          0
# 168    Timor-Leste          0

# %%
# SHOW WHO REGION  DATA BY VIZ 

sns.pairplot(df,hue='WHO Region')

# %% [markdown]
# # which who region have max or min confirmed case

# %%
# FIND CONFIRMED CASE IN WHO REGION WISE.

europe_confirm=df.loc[df['WHO Region']=='Europe']['Confirmed'].sum()
easter_confirm=df.loc[df['WHO Region']=='Eastern Mediterranean']['Confirmed'].sum()
africa_confirm=df.loc[df['WHO Region']=='Africa']['Confirmed'].sum()
america_confirm=df.loc[df['WHO Region']=='Americas']['Confirmed'].sum()
western_confirm=df.loc[df['WHO Region']=='Western Pacific']['Confirmed'].sum()
south_est_asia=df.loc[df['WHO Region']=='South-East Asia']['Confirmed'].sum()
data=(europe_confirm,easter_confirm,africa_confirm,america_confirm,western_confirm,south_est_asia)
mylabels=('Europe','Eastern Mediterranean','Africa','Western Pacific','Americas','South-East Asia')
plt.pie(data,labels=mylabels,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2e8f7dc3730>,
# ...
#  [Text(0.8894962314302804, 0.6471448479833005, 'Europe'),
#   Text(0.03154363004404588, 1.0995476339857426, 'Eastern Mediterranean'),
#   Text(-0.42161774584125616, 1.0159913761404364, 'Africa'),
#   Text(-0.8787395596931424, -0.661677252314376, 'Western Pacific'),
#   Text(0.8007585152449472, -0.7541788914194747, 'Americas'),
#   Text(1.0333652046261037, -0.3770362765942438, 'South-East Asia')],
#  [Text(0.48517976259833473, 0.35298809889998206, '20.02'),
#   Text(0.01720561638766139, 0.599753254901314, '9.05'),
#   Text(-0.2299733159134124, 0.5541771142584199, '4.39'),
#   Text(-0.47931248710535035, -0.3609148648987505, '53.63'),
#   Text(0.43677737195178934, -0.4113703044106225, '1.77'),
#   Text(0.5636537479778746, -0.20565615086958752, '11.14')])

# %% [markdown]
# Western pacific has max confirned case and america has min

# %% [markdown]
# # Top 10 most active case  country

# %%
active_country =df[['Country/Region','Active']].sort_values(by=['Active'],ascending=False).head(10)

# %%
active_country
# Out:
#      Country/Region   Active
# 173              US  2816444
# 23           Brazil   508116
# 79            India   495499
# 177  United Kingdom   254427
# 138          Russia   201097
# 154    South Africa   170537
# 37         Colombia   117163
# 61           France   108928
# 32           Canada   107514
# 132            Peru    98752

# %%
import plotly.express as  px

# %%
fig = px.bar(active_country, x='Active', y='Country/Region',color='Country/Region', title='Top 10 Countries of Most Active Cases')
fig.show()
# Out:
# <div>                            <div id="d9666f1e-64ff-4fea-a737-1d95b8636143" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9666f1e-64ff-4fea-a737-1d95b8636143")) {                    Plotly.newPlot(                        "d9666f1e-64ff-4fea-a737-1d95b8636143",                        [{"alignmentgroup":"True","hovertemplate":"Country/Region=%{y}<br>Active=%{x}<extra></extra>","legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"h","showlegend":true,"textposition":"auto","x":[2816444],"xaxis":"x","y":["US"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country/Region=%{y}<br>Active=%{x}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#EF553B","patter
# ...

# %% [markdown]
# # Top 10 most Confirmed case country

# %%
confirm_country =df[['Country/Region','Confirmed']].sort_values(by=['Confirmed'],ascending=False).head(10)

# %%
confirm_country
# Out:
#      Country/Region  Confirmed
# 173              US    4290259
# 23           Brazil    2442375
# 79            India    1480073
# 138          Russia     816680
# 154    South Africa     452529
# 111          Mexico     395489
# 132            Peru     389717
# 35            Chile     347923
# 177  United Kingdom     301708
# 81             Iran     293606

# %%
plt.title("Top 10 most Confirmed case country" , fontsize=40)
sns.barplot(x='Country/Region', y='Confirmed', data=confirm_country)
# Out:
# <AxesSubplot:title={'center':'Top 10 most Confirmed case country'}, xlabel='Country/Region', ylabel='Confirmed'>

# %% [markdown]
# # Top 10 Countries of Deaths Case

# %%
death_country =df[['Country/Region','Deaths']].sort_values(by=['Deaths'],ascending=False).head(10)

# %%
death_country
# Out:
#      Country/Region  Deaths
# 173              US  148011
# 23           Brazil   87618
# 177  United Kingdom   45844
# 111          Mexico   44022
# 85            Italy   35112
# 79            India   33408
# 61           France   30212
# 157           Spain   28432
# 132            Peru   18418
# 81             Iran   15912

# %%
fig = px.bar(death_country, x='Deaths', y='Country/Region',color='Country/Region', title='Top 10 Countries of Most Active Cases')

# %%
fig
# Out:
# <div>                            <div id="ca60a215-4de1-4806-b2c0-4306550c2ed4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca60a215-4de1-4806-b2c0-4306550c2ed4")) {                    Plotly.newPlot(                        "ca60a215-4de1-4806-b2c0-4306550c2ed4",                        [{"alignmentgroup":"True","hovertemplate":"Country/Region=%{y}<br>Deaths=%{x}<extra></extra>","legendgroup":"US","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US","offsetgroup":"US","orientation":"h","showlegend":true,"textposition":"auto","x":[148011],"xaxis":"x","y":["US"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country/Region=%{y}<br>Deaths=%{x}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#EF553B","pattern
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Top 10 Countries of Most Recovered Cases

# %%
recover_country =df[['Country/Region','Recovered']].sort_values(by=['Recovered'],ascending=False).head(10)

# %%
recover_country
# Out:
#     Country/Region  Recovered
# 23          Brazil    1846641
# 173             US    1325804
# 79           India     951166
# 138         Russia     602249
# 35           Chile     319954
# 111         Mexico     303810
# 154   South Africa     274925
# 132           Peru     272547
# 81            Iran     255144
# 128       Pakistan     241026

# %%
plt.title("Top 10 most Recovered case country" , fontsize=40)
sns.barplot(x='Country/Region', y='Recovered', data=recover_country)
# Out:
# <AxesSubplot:title={'center':'Top 10 most Recovered case country'}, xlabel='Country/Region', ylabel='Recovered'>

# %% [markdown]
# # Conclusion
# 1.There are 187 countries are which belongs to 06 WHO regions and there are total 82cr no of cases and there are total deaths no are 4cr and total recovered cases are 38cr
#
# 2.In US maximum no of cases in a day are 2 lakh. and death cases are in a single day are 1 lakh.
#
# 3.In Brazil maximum no of cases are 18lakh. WHO has confirmed that America has maximum no of cases and minimum cases are in Western Pacific region and maximum deaths are in America and lesseer deaths on Africa region.
#
# 4.In India there are 14 laks confirmed cases and death no are 33k. and receovered cases in India are 95k and active cases are 4 lakh.
